# %%
import sys
import os

# %cd /media/mohamed-gaber/01D96E17175F8760/Artifitial_intelligence/GraduationProject
# Out:
# /media/mohamed-gaber/01D96E17175F8760/Artifitial_intelligence/GraduationProject

# %%
import os
from src.Config.config import NEO4J_USERNAME , NEO4J_URI , NEO4J_PASSWORD
from src.LLMs.Qwen_Model import ArabicModel

# %%
os.environ['NEO4J_URI'] = NEO4J_URI
os.environ['NEO4J_USERNAME'] = NEO4J_USERNAME
os.environ['NEO4J_PASSWORD'] = NEO4J_PASSWORD

# %%
from langchain_neo4j import Neo4jGraph

graph = Neo4jGraph(
    url=NEO4J_URI,
    username=NEO4J_USERNAME,
    password=NEO4J_PASSWORD
)
graph

# %%
llm = ArabicModel()
ar_llm = llm.get_ar_llm()
